# %% [markdown]
# # Logistic rawdata procsessing
#
# this code take the rawdata generated by the Logistic simulation code and creates pandas Dataframes for evaluation

# %%
import os
import pandas as pd
import numpy as np
from collections import defaultdict

# %%
# Step 0 for memory reason the data is processed in 3 batches => split by b
#b_case = "b0.1"
#b_case = "b0.01"
#b_case = "bAUTO"

# %%
# Step 1: Specify the directory containing the CSV files
directory = r'G:\My Drive\Studium\UNIGE_Master\Thesis\Master_Thesis\Data\Logistic_Data_raw'

# %%
# Step 2: List all files in the directory
all_files = os.listdir(directory)

# %%
# Step 3: Group files by their common components except the ID


file_groups = defaultdict(list)
for file in all_files:
    if (file.endswith('.csv')):
        parts = file.split('_')
        key = '_'.join(parts[:-1])  # Everything except the last part (ID)
        file_groups[key].append(file)

# %%
# Step 4: Read and stack files within each group, adding columns for the components
stacked_dataframes = []
count = 0
for key, files in file_groups.items():
    dataframes = []
    for file in sorted(files, key=lambda x: int(x.split('_')[-1].split('.')[0][2:])):
        df = pd.read_csv(os.path.join(directory, file),index_col=False)
    
        df = df.drop(["Unnamed: 0", "b","time", "MMD"], axis=1)
        
        # Extract components from the filename
        parts = file.split('_')

        components = {
            'alpha': np.repeat(float(parts[0][5:]), df.shape[0]),
            'dim':np.repeat(int(parts[1][3:]),df.shape[0]),
            'b': np.repeat(parts[2],df.shape[0]),
            'xsize': np.repeat(int(parts[3][5:]),df.shape[0]),
            'ysize': np.repeat(int(parts[4][5:]),df.shape[0]),
            'ID': np.repeat(int(parts[5].split('.')[0][2:]),df.shape[0])  # Remove the .csv part
        }

        flag_df = pd.DataFrame.from_dict(components)

        df_flags_attached = pd.concat([df,flag_df], axis=1)
        
        dataframes.append(df_flags_attached)



        

        

    
    # Concatenate dataframes
    stacked_df = pd.concat(dataframes, ignore_index=True)
    stacked_dataframes.append(stacked_df)
    
    count += 1

    print(f"loaded and processed {count} simulation")

    
    


# Now `stacked_dataframes` is a list of stacked dataframes with additional columns for the components.

# stack everything => same name for ram issue...
stacked_dataframes = pd.concat(stacked_dataframes)
# Out:
# loaded and processed 1 simulation
# loaded and processed 2 simulation
# loaded and processed 3 simulation
# loaded and processed 4 simulation
# loaded and processed 5 simulation
# loaded and processed 6 simulation
# loaded and processed 7 simulation
# loaded and processed 8 simulation
# loaded and processed 9 simulation
# loaded and processed 10 simulation
# loaded and processed 11 simulation
# loaded and processed 12 simulation
# loaded and processed 13 simulation
# loaded and processed 14 simulation
# loaded and processed 15 simulation
# loaded and processed 16 simulation
# loaded and processed 17 simulation
# loaded and processed 18 simulation
# loaded and processed 19 simulation
# loaded and processed 20 simulation
# loaded and processed 21 simulation
# loaded and processed 22 simulation
# loaded and processed 23 simulation
# loaded and processed 24 simulation
# loaded and processed 25 simulation
# loaded and processed 26 simulation
# loaded and processed 27 simulation
# loaded and processed 28 simulation
# loaded and processed 29 simulation
# loaded and processed 30 simulation
# loaded and processed 31 simulation
# loaded and processed 32 simulation
# loaded and processed 33 simulation
# loaded and processed 34 simulation
# loaded and processed 35 simulation
# loaded and processed 36 simulation
# loaded and processed 37 simulation
# loaded and processed 38 simulation
# loaded and processed 39 simulation
# loaded and processed 40 simulation
# loaded and processed 41 simulation
# loaded and processed 42 simulation
# loaded and processed 43 simulation
# loaded and processed 44 simulation
# loaded and processed 45 simulation
# loaded and processed 46 simulation
# loaded and processed 47 simulation
# loaded and processed 48 simulation
# loaded and processed 49 simulation
# loaded and processed 50 simulation
# loaded and processed 51 simulation
# loaded and processed 52 simulation
# loaded and processed 53 simulation
# loaded and processed 54 simulation
# loaded and processed 55 simulation
# loaded and processed 56 simulation
# loaded and processed 57 simulation
# loaded and processed 58 simulation
# loaded and processed 59 simulation
# loaded and processed 60 simulation
# loaded and processed 61 simulation
# loaded and processed 62 simulation
# loaded and processed 63 simulation
# loaded and processed 64 simulation
# loaded and processed 65 simulation
# loaded and processed 66 simulation
# loaded and processed 67 simulation
# loaded and processed 68 simulation
# loaded and processed 69 simulation
# loaded and processed 70 simulation
# loaded and processed 71 simulation
# loaded and processed 72 simulation
# loaded and processed 73 simulation
# loaded and processed 74 simulation
# loaded and processed 75 simulation
# loaded and processed 76 simulation
# loaded and processed 77 simulation
# loaded and processed 78 simulation
# loaded and processed 79 simulation
# loaded and processed 80 simulation
# loaded and processed 81 simulation
# loaded and processed 82 simulation
# loaded and processed 83 simulation
# loaded and processed 84 simulation
# loaded and processed 85 simulation
# loaded and processed 86 simulation
# loaded and processed 87 simulation
# loaded and processed 88 simulation
# loaded and processed 89 simulation
# loaded and processed 90 simulation
# loaded and processed 91 simulation
# loaded and processed 92 simulation
# loaded and processed 93 simulation
# loaded and processed 94 simulation
# loaded and processed 95 simulation
# loaded and processed 96 simulation
# loaded and processed 97 simulation
# loaded and processed 98 simulation
# loaded and processed 99 simulation
# loaded and processed 100 simulation
# loaded and processed 101 simulation
# loaded and processed 102 simulation
# loaded and processed 103 simulation
# loaded and processed 104 simulation
# loaded and processed 105 simulation
# loaded and processed 106 simulation
# loaded and processed 107 simulation
# loaded and processed 108 simulation
# loaded and processed 109 simulation
# loaded and processed 110 simulation
# loaded and processed 111 simulation
# loaded and processed 112 simulation
# loaded and processed 113 simulation
# loaded and processed 114 simulation
# loaded and processed 115 simulation
# loaded and processed 116 simulation
# loaded and processed 117 simulation
# loaded and processed 118 simulation
# loaded and processed 119 simulation
# loaded and processed 120 simulation
# loaded and processed 121 simulation
# loaded and processed 122 simulation
# loaded and processed 123 simulation
# loaded and processed 124 simulation
# loaded and processed 125 simulation
# loaded and processed 126 simulation
# loaded and processed 127 simulation
# loaded and processed 128 simulation
# loaded and processed 129 simulation
# loaded and processed 130 simulation
# loaded and processed 131 simulation
# loaded and processed 132 simulation
# loaded and processed 133 simulation
# loaded and processed 134 simulation
# loaded and processed 135 simulation
# loaded and processed 136 simulation
# loaded and processed 137 simulation
# loaded and processed 138 simulation
# loaded and processed 139 simulation
# loaded and processed 140 simulation
# loaded and processed 141 simulation
# loaded and processed 142 simulation
# loaded and processed 143 simulation
# loaded and processed 144 simulation
# loaded and processed 145 simulation
# loaded and processed 146 simulation
# loaded and processed 147 simulation
# loaded and processed 148 simulation
# loaded and processed 149 simulation
# loaded and processed 150 simulation
# loaded and processed 151 simulation
# loaded and processed 152 simulation
# loaded and processed 153 simulation
# loaded and processed 154 simulation
# loaded and processed 155 simulation
# loaded and processed 156 simulation
# loaded and processed 157 simulation
# loaded and processed 158 simulation
# loaded and processed 159 simulation
# loaded and processed 160 simulation
# loaded and processed 161 simulation
# loaded and processed 162 simulation
# loaded and processed 163 simulation
# loaded and processed 164 simulation
# loaded and processed 165 simulation
# loaded and processed 166 simulation
# loaded and processed 167 simulation
# loaded and processed 168 simulation
# loaded and processed 169 simulation
# loaded and processed 170 simulation
# loaded and processed 171 simulation
# loaded and processed 172 simulation
# loaded and processed 173 simulation
# loaded and processed 174 simulation
# loaded and processed 175 simulation
# loaded and processed 176 simulation
# loaded and processed 177 simulation
# loaded and processed 178 simulation
# loaded and processed 179 simulation
# loaded and processed 180 simulation
# loaded and processed 181 simulation
# loaded and processed 182 simulation
# loaded and processed 183 simulation
# loaded and processed 184 simulation
# loaded and processed 185 simulation
# loaded and processed 186 simulation
# loaded and processed 187 simulation
# loaded and processed 188 simulation
# loaded and processed 189 simulation
# loaded and processed 190 simulation
# loaded and processed 191 simulation
# loaded and processed 192 simulation
# loaded and processed 193 simulation
# loaded and processed 194 simulation
# loaded and processed 195 simulation
# loaded and processed 196 simulation
# loaded and processed 197 simulation
# loaded and processed 198 simulation
# loaded and processed 199 simulation
# loaded and processed 200 simulation
# loaded and processed 201 simulation
# loaded and processed 202 simulation
# loaded and processed 203 simulation
# loaded and processed 204 simulation
# loaded and processed 205 simulation
# loaded and processed 206 simulation
# loaded and processed 207 simulation
# loaded and processed 208 simulation
# loaded and processed 209 simulation
# loaded and processed 210 simulation
# loaded and processed 211 simulation
# loaded and processed 212 simulation
# loaded and processed 213 simulation
# loaded and processed 214 simulation
# loaded and processed 215 simulation
# loaded and processed 216 simulation
# loaded and processed 217 simulation
# loaded and processed 218 simulation
# loaded and processed 219 simulation
# loaded and processed 220 simulation
# loaded and processed 221 simulation
# loaded and processed 222 simulation
# loaded and processed 223 simulation
# loaded and processed 224 simulation
# loaded and processed 225 simulation
# loaded and processed 226 simulation
# loaded and processed 227 simulation
# loaded and processed 228 simulation
# loaded and processed 229 simulation
# loaded and processed 230 simulation
# loaded and processed 231 simulation
# loaded and processed 232 simulation
# loaded and processed 233 simulation
# loaded and processed 234 simulation
# loaded and processed 235 simulation
# loaded and processed 236 simulation
# loaded and processed 237 simulation
# loaded and processed 238 simulation
# loaded and processed 239 simulation
# loaded and processed 240 simulation
# loaded and processed 241 simulation
# loaded and processed 242 simulation
# loaded and processed 243 simulation
# loaded and processed 244 simulation
# loaded and processed 245 simulation
# loaded and processed 246 simulation
# loaded and processed 247 simulation
# loaded and processed 248 simulation
# loaded and processed 249 simulation
# loaded and processed 250 simulation
# loaded and processed 251 simulation
# loaded and processed 252 simulation
# loaded and processed 253 simulation
# loaded and processed 254 simulation
# loaded and processed 255 simulation
# loaded and processed 256 simulation
# loaded and processed 257 simulation
# loaded and processed 258 simulation
# loaded and processed 259 simulation
# loaded and processed 260 simulation
# loaded and processed 261 simulation
# loaded and processed 262 simulation
# loaded and processed 263 simulation
# loaded and processed 264 simulation
# loaded and processed 265 simulation
# loaded and processed 266 simulation
# loaded and processed 267 simulation
# loaded and processed 268 simulation
# loaded and processed 269 simulation
# loaded and processed 270 simulation
# loaded and processed 271 simulation
# loaded and processed 272 simulation
# loaded and processed 273 simulation
# loaded and processed 274 simulation
# loaded and processed 275 simulation
# loaded and processed 276 simulation
# loaded and processed 277 simulation
# loaded and processed 278 simulation
# loaded and processed 279 simulation
# loaded and processed 280 simulation
# loaded and processed 281 simulation
# loaded and processed 282 simulation
# loaded and processed 283 simulation
# loaded and processed 284 simulation
# loaded and processed 285 simulation
# loaded and processed 286 simulation
# loaded and processed 287 simulation
# loaded and processed 288 simulation
# loaded and processed 289 simulation
# loaded and processed 290 simulation
# loaded and processed 291 simulation
# loaded and processed 292 simulation
# loaded and processed 293 simulation
# loaded and processed 294 simulation
# loaded and processed 295 simulation
# loaded and processed 296 simulation
# loaded and processed 297 simulation
# loaded and processed 298 simulation
# loaded and processed 299 simulation
# loaded and processed 300 simulation
# loaded and processed 301 simulation
# loaded and processed 302 simulation
# loaded and processed 303 simulation
# loaded and processed 304 simulation
# loaded and processed 305 simulation
# loaded and processed 306 simulation
# loaded and processed 307 simulation
# loaded and processed 308 simulation
# loaded and processed 309 simulation
# loaded and processed 310 simulation
# loaded and processed 311 simulation
# loaded and processed 312 simulation
# loaded and processed 313 simulation
# loaded and processed 314 simulation
# loaded and processed 315 simulation
# loaded and processed 316 simulation
# loaded and processed 317 simulation
# loaded and processed 318 simulation
# loaded and processed 319 simulation
# loaded and processed 320 simulation
# loaded and processed 321 simulation
# loaded and processed 322 simulation
# loaded and processed 323 simulation
# loaded and processed 324 simulation
# loaded and processed 325 simulation
# loaded and processed 326 simulation
# loaded and processed 327 simulation
# loaded and processed 328 simulation
# loaded and processed 329 simulation
# loaded and processed 330 simulation
# loaded and processed 331 simulation
# loaded and processed 332 simulation
# loaded and processed 333 simulation
# loaded and processed 334 simulation
# loaded and processed 335 simulation
# loaded and processed 336 simulation
# loaded and processed 337 simulation
# loaded and processed 338 simulation
# loaded and processed 339 simulation
# loaded and processed 340 simulation
# loaded and processed 341 simulation
# loaded and processed 342 simulation
# loaded and processed 343 simulation
# loaded and processed 344 simulation
# loaded and processed 345 simulation
# loaded and processed 346 simulation
# loaded and processed 347 simulation
# loaded and processed 348 simulation
# loaded and processed 349 simulation
# loaded and processed 350 simulation
# loaded and processed 351 simulation
# loaded and processed 352 simulation
# loaded and processed 353 simulation
# loaded and processed 354 simulation
# loaded and processed 355 simulation
# loaded and processed 356 simulation
# loaded and processed 357 simulation
# loaded and processed 358 simulation
# loaded and processed 359 simulation
# loaded and processed 360 simulation
# loaded and processed 361 simulation
# loaded and processed 362 simulation
# loaded and processed 363 simulation
# loaded and processed 364 simulation
# loaded and processed 365 simulation
# loaded and processed 366 simulation
# loaded and processed 367 simulation
# loaded and processed 368 simulation
# loaded and processed 369 simulation
# loaded and processed 370 simulation
# loaded and processed 371 simulation
# loaded and processed 372 simulation
# loaded and processed 373 simulation
# loaded and processed 374 simulation
# loaded and processed 375 simulation

# %%
stacked_dataframes
# Out:
#         alpha_hat  alpha  dim      b  xsize  ysize   ID
# 0        0.400000   0.05   20  bAUTO    200     50    1
# 1        0.305216   0.05   20  bAUTO    200     50    1
# 2        0.216138   0.05   20  bAUTO    200     50    1
# 3        0.131669   0.05   20  bAUTO    200     50    1
# 4        0.054441   0.05   20  bAUTO    200     50    1
# ...           ...    ...  ...    ...    ...    ...  ...
# 119995        NaN   0.95    5  bAUTO   1000    500  150
# 119996        NaN   0.95    5  bAUTO   1000    500  150
# 119997        NaN   0.95    5  bAUTO   1000    500  150
# 119998        NaN   0.95    5  bAUTO   1000    500  150
# 119999        NaN   0.95    5  bAUTO   1000    500  150
#
# [45000000 rows x 7 columns]

# %%
stacked_dataframes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 45000000 entries, 0 to 119999
# Data columns (total 7 columns):
#  #   Column     Dtype
# ---  ------     -----
#  0   alpha_hat  float64
#  1   alpha      float64
#  2   dim        int32
#  3   b          object
#  4   xsize      int32
#  5   ysize      int32
#  6   ID         int32
# dtypes: float64(2), int32(4), object(1)
# memory usage: 2.0+ GB

# %%
# 5 step: safe the processed DataFrame
file_name = f"Logistic_Processed_data"
saving_path = r"G:\My Drive\Studium\UNIGE_Master\Thesis\Master_Thesis\Data\Logistic_Data_processed"

stacked_dataframes.to_csv(f"{saving_path}\{file_name}.csv")

# %%
stacked_dataframes.to_pickle(f"{saving_path}\{file_name}.pkl")
# Out:
# <string>:1: SyntaxWarning: invalid escape sequence '\{'
# <>:1: SyntaxWarning: invalid escape sequence '\{'
# <string>:1: SyntaxWarning: invalid escape sequence '\{'
# <>:1: SyntaxWarning: invalid escape sequence '\{'
# C:\Users\nickk\AppData\Local\Temp\ipykernel_16492\2723069148.py:1: SyntaxWarning: invalid escape sequence '\{'
#   stacked_dataframes.to_pickle(f"{saving_path}\{file_name}.pkl")
