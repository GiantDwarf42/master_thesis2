# %% [markdown]
# # Logistics Results
#
# This notebook is analyzing the Gaussian simulation study

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
pd.set_option('display.max_rows', 500)

# %% [markdown]
# # Notes
#
# * b very important for numerical reasons => b0.1 the worst. AUTO and b0.01 similar, AUTO probably best
# * b0.1 case arguably unusable because of numeric reasons
# * b0.01 did converge (mostly) and was a lot more stable numerically, bigger d better convergence more information?
# 	=> bigger simulation sample size better estimator maybe?
# 	=> bigger target sample size better estimator maybe?
# 	=> kinda all over the place
#
# * bAUTO alpha 0.1 case did not converge properly, almost no numeric issue
# * big influence of the d parameter, probably better estimator with better target sample size and better simulation sample size

# %%
load_path = r"G:\My Drive\Studium\UNIGE_Master\Thesis\Master_Thesis\Code2\processed_tables\Logistics_result_b0.1.pkl"
df_b01 = pd.read_pickle(load_path)

load_path = r"G:\My Drive\Studium\UNIGE_Master\Thesis\Master_Thesis\Code2\processed_tables\Logistics_result_b0.01.pkl"
df_b001 = pd.read_pickle(load_path)

load_path = r"G:\My Drive\Studium\UNIGE_Master\Thesis\Master_Thesis\Code2\processed_tables\Logistics_result_bAUTO.pkl"
df_bAUTO = pd.read_pickle(load_path)

# %%
# Combine the two levels of the column MultiIndex into a single level
df_b01.columns = ['_'.join(filter(None, col)).strip() for col in df_b01.columns.values]

# Remove the prefix 'alpha_hat_' from the relevant columns
df_b01.columns = [col.replace('alpha_hat_', '') for col in df_b01.columns]

df_b01.set_index(["alpha", "dim", "b", "xsize", "ysize"]).head()
# Out:
#                             count      mean       std
# alpha dim b    xsize ysize
# 0.1   1   b0.1 50    50       137  0.635707  0.452436
#                100   50       131  0.615532  0.459163
#                      100      132  0.615089  0.451286
#                200   50       125  0.571816  0.473713
#                      100      127  0.643005  0.439207

# %%
df_b01.set_index(["alpha", "dim", "b", "xsize", "ysize"]).head()
# Out:
#                             count      mean       std
# alpha dim b    xsize ysize
# 0.1   1   b0.1 50    50       137  0.635707  0.452436
#                100   50       131  0.615532  0.459163
#                      100      132  0.615089  0.451286
#                200   50       125  0.571816  0.473713
#                      100      127  0.643005  0.439207

# %%
df_b01_reduced = df_b01[~(df_b01["dim"]==1)]
df_b01_reduced_set_index = df_b01_reduced.set_index(["alpha", "dim", "b", "xsize", "ysize"])
df_b01_reduced_set_index.head()
# Out:
#                             count      mean       std
# alpha dim b    xsize ysize
# 0.1   2   b0.1 50    50       130  0.297046  0.265896
#                100   50       122  0.287789  0.259519
#                      100      128  0.303189  0.225013
#                200   50       119  0.376511  0.287300
#                      100      122  0.313604  0.227790

# %%
latex_df = df_b01_reduced_set_index

# %%
# Step 2: Flatten the MultiIndex to avoid \multirow issues
latex_header = [' & '.join([str(level) for level in header]) for header in latex_df.index.names]
latex_header = ' & '.join(latex_header) + ' \\\\ \n'

# Step 3: Convert DataFrame to LaTeX format with float_format
latex_code = latex_df.to_latex(multicolumn=False, multirow=False, float_format="{:.3f}".format)

# Step 4: Manually insert the custom header into the LaTeX code
latex_code = latex_code.replace(r'\toprule', r'\toprule' + latex_header)

# Option 1: Use \resizebox to fit the table to the text width
latex_code = (
    r"\begin{table}[htbp]" "\n"  # Start the table environment
    r"\centering" "\n"           # Center the table
    r"\resizebox{\textwidth}{!}{"  # Start the resizebox command
    + latex_code +                 # Add the LaTeX table code
    r"}" "\n"                       # Close the resizebox command
    r"\caption{Your Caption Here}" "\n"  # Add your caption here
    r"\label{tab:your_label_here}" "\n"  # Add a label for referencing
    r"\end{table}"                 # End the table environment
)

# Step 5: Define the folder and filename where you want to save the file

folder_path = r'G:\My Drive\Studium\UNIGE_Master\Thesis\Master_Thesis\Data\Logistics_server'
file_name = 'Logistic_0.1.txt'



# Step 6: Save the LaTeX code to the specified folder as a .txt file
file_path = os.path.join(folder_path, file_name)
with open(file_path, 'w') as file:
    file.write(latex_code)

print(f"LaTeX code saved to {file_path}")
# Out:
# LaTeX code saved to G:\My Drive\Studium\UNIGE_Master\Thesis\Master_Thesis\Data\Logistics_server\Logistic_0.1.txt

# %%
# Step 2: Flatten the MultiIndex to avoid \multirow issues
latex_header = [' & '.join([str(level) for level in header]) for header in latex_df.index.names]
latex_header = ' & '.join(latex_header) + ' \\\\ \n'

# Step 3: Convert DataFrame to LaTeX format with float_format
latex_code = latex_df.to_latex(multicolumn=False, multirow=False, float_format="{:.3f}".format)

# Step 4: Manually insert the custom header into the LaTeX code
latex_code = latex_code.replace(r'\toprule', r'\toprule' + latex_header)

# Option 1: 
latex_code = (
    r"\begin{table}[htbp]" "\n"
    r"\centering" "\n"
    r"\scalebox{0.8}{"  # Scale the table to 80% of its original size
    + latex_code +
    r"}" "\n"
    r"\caption{Your Caption Here}" "\n"
    r"\label{tab:your_label_here}" "\n"
    r"\end{table}"
)

# Step 5: Define the folder and filename where you want to save the file

folder_path = r'G:\My Drive\Studium\UNIGE_Master\Thesis\Master_Thesis\Data\Logistics_server'
file_name = 'Logistic_0.1.txt'



# Step 6: Save the LaTeX code to the specified folder as a .txt file
file_path = os.path.join(folder_path, file_name)
with open(file_path, 'w') as file:
    file.write(latex_code)

print(f"LaTeX code saved to {file_path}")
# Out:
# LaTeX code saved to G:\My Drive\Studium\UNIGE_Master\Thesis\Master_Thesis\Data\Logistics_server\Logistic_0.1.txt

# %%
# Step 2: Flatten the MultiIndex to avoid \multirow issues
latex_header = [' & '.join([str(level) for level in header]) for header in latex_df.index.names]
latex_header = ' & '.join(latex_header) + ' \\\\ \n'

# Step 3: Convert DataFrame to LaTeX format with float_format
latex_code = latex_df.to_latex(multicolumn=False, multirow=False, float_format="{:.3f}".format)

# Step 4: Manually insert the custom header into the LaTeX code
latex_code = latex_code.replace(r'\toprule', r'\toprule' + latex_header)

# Option 1: 
latex_code = (
    r"\begin{longtable}{|c|c|c|}" "\n"  # Define your column alignment
    r"\hline" "\n"
    r"Header 1 & Header 2 & Header 3 \\" "\n"  # Table headers
    r"\hline" "\n"
    r"\endfirsthead" "\n"  # Define the first head
    r"\hline" "\n"
    r"Header 1 & Header 2 & Header 3 \\" "\n"  # Repeat headers on new pages
    r"\hline" "\n"
    r"\endhead" "\n"
    r"\hline" "\n"
    r"\endfoot" "\n"
    r"\hline" "\n"
    r"\endlastfoot" "\n"
    + latex_code +
    r"\end{longtable}"
)

# Step 5: Define the folder and filename where you want to save the file

folder_path = r'G:\My Drive\Studium\UNIGE_Master\Thesis\Master_Thesis\Data\Logistics_server'
file_name = 'Logistic_0.1.txt'



# Step 6: Save the LaTeX code to the specified folder as a .txt file
file_path = os.path.join(folder_path, file_name)
with open(file_path, 'w') as file:
    file.write(latex_code)

print(f"LaTeX code saved to {file_path}")
# Out:
# LaTeX code saved to G:\My Drive\Studium\UNIGE_Master\Thesis\Master_Thesis\Data\Logistics_server\Logistic_0.1.txt

# %%
# Step 2: Flatten the MultiIndex to avoid \multirow issues
latex_header = [' & '.join([str(level) for level in header]) for header in latex_df.index.names]
latex_header = ' & '.join(latex_header) + ' \\\\ \n'

# Step 3: Convert DataFrame to LaTeX format with float_format
latex_code = latex_df.to_latex(multicolumn=False, multirow=False, float_format="{:.3f}".format)

# Step 4: Manually insert the custom header into the LaTeX code
latex_code = latex_code.replace(r'\toprule', r'\toprule' + latex_header)

# Option 1: 
latex_code = (
    r"\begin{xtabular}{|c|c|c|}" "\n"  # Define the xtabular table
    r"\hline" "\n"
    r"Header 1 & Header 2 & Header 3 \\" "\n"
    r"\hline" "\n"
    + latex_code +  # Insert the LaTeX table rows here
    r"\end{xtabular}" "\n"
)

# Step 5: Define the folder and filename where you want to save the file

folder_path = r'G:\My Drive\Studium\UNIGE_Master\Thesis\Master_Thesis\Data\Logistics_server'
file_name = 'Logistic_0.1.txt'



# Step 6: Save the LaTeX code to the specified folder as a .txt file
file_path = os.path.join(folder_path, file_name)
with open(file_path, 'w') as file:
    file.write(latex_code)

print(f"LaTeX code saved to {file_path}")
# Out:
# LaTeX code saved to G:\My Drive\Studium\UNIGE_Master\Thesis\Master_Thesis\Data\Logistics_server\Logistic_0.1.txt

# %%
# Step 2: Flatten the MultiIndex to avoid \multirow issues
latex_header = [' & '.join([str(level) for level in header]) for header in latex_df.index.names]
latex_header = ' & '.join(latex_header) + ' \\\\ \n'

# Step 3: Convert DataFrame to LaTeX format with float_format
latex_code = latex_df.to_latex(multicolumn=False, multirow=False, float_format="{:.3f}".format)

# Step 4: Manually insert the custom header into the LaTeX code
latex_code = latex_code.replace(r'\toprule', r'\toprule' + latex_header)

# Option 1: 
latex_code = (
    r"\tablefirsthead{\hline Header 1 & Header 2 & Header 3 \\ \hline}" "\n"
    r"\tablehead{\hline Header 1 & Header 2 & Header 3 \\ \hline}" "\n"
    r"\tabletail{\hline}" "\n"
    r"\tablelasttail{\hline}" "\n"
    r"\begin{supertabular}{|c|c|c|}" "\n"  # Define the supertabular table
    + latex_code +  # Insert the LaTeX table rows here
    r"\end{supertabular}" "\n"
)


# Step 5: Define the folder and filename where you want to save the file

folder_path = r'G:\My Drive\Studium\UNIGE_Master\Thesis\Master_Thesis\Data\Logistics_server'
file_name = 'Logistic_0.1.txt'



# Step 6: Save the LaTeX code to the specified folder as a .txt file
file_path = os.path.join(folder_path, file_name)
with open(file_path, 'w') as file:
    file.write(latex_code)

print(f"LaTeX code saved to {file_path}")
# Out:
# LaTeX code saved to G:\My Drive\Studium\UNIGE_Master\Thesis\Master_Thesis\Data\Logistics_server\Logistic_0.1.txt

# %%
# Combine the two levels of the column MultiIndex into a single level
df_b001.columns = ['_'.join(filter(None, col)).strip() for col in df_b001.columns.values]

# Remove the prefix 'alpha_hat_' from the relevant columns
df_b001.columns = [col.replace('alpha_hat_', '') for col in df_b001.columns]

df_b001.set_index(["alpha", "dim", "b", "xsize", "ysize"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_21224\2723600355.py in ?()
#       3
#       4 # Remove the prefix 'alpha_hat_' from the relevant columns
#       5 df_b001.columns = [col.replace('alpha_hat_', '') for col in df_b001.columns]
#       6
# ----> 7 df_b001.set_index(["alpha", "dim", "b", "xsize", "ysize"])
#
# c:\Users\nickk\anaconda3\envs\mt\Lib\site-packages\pandas\core\frame.py in ?(self, keys, drop, append, inplace, verify_integrity)
#    6105                     if not found:
#    6106                         missing.append(col)
#    6107
#    6108         if missing:
# -> 6109             raise KeyError(f"None of {missing} are in the columns")
#    6110
#    6111         if inplace:
#    6112             frame = self
#
# KeyError: "None of ['alpha', 'dim', 'xsize', 'ysize'] are in the columns"

# %%
# Combine the two levels of the column MultiIndex into a single level
df_bAUTO.columns = ['_'.join(filter(None, col)).strip() for col in df_bAUTO.columns.values]

# Remove the prefix 'alpha_hat_' from the relevant columns
df_bAUTO.columns = [col.replace('alpha_hat_', '') for col in df_bAUTO.columns]

df_bAUTO.set_index(["alpha", "dim", "b", "xsize", "ysize"])
# Out:
#                              count      mean       std
# alpha dim b     xsize ysize
# 0.1   1   bAUTO 50    50       199  0.671309  0.395982
#                 100   50       200  0.688842  0.385181
#                       100      199  0.729942  0.349448
#                 200   50       196  0.729333  0.371072
#                       100      198  0.747864  0.339593
#                       200      199  0.799888  0.279551
#                 500   50       193  0.684954  0.391988
#                       100      197  0.729056  0.347724
#                       200      199  0.809222  0.264450
#                       500      200  0.862682  0.160894
#                 1000  50       189  0.756186  0.342667
#                       100      193  0.776618  0.317897
#                       200      194  0.848793  0.221618
#                       500      198  0.891444  0.096699
#                       1000     200  0.890873  0.061467
#       2   bAUTO 50    50       200  0.357148  0.245801
# ...
